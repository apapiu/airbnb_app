# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn.externals import joblib

import folium
from folium import plugins

import matplotlib.pyplot as plt

home_folder = os.environ["home_folder"]
sys.path.append(os.path.join(home_folder, "airbnb_app/airbnb/web_app/flaskexample/"))
import airbnb_pipeline

#sql stuff:
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
listings.head()
# Out:
#          id                              neighborhood_overview  price  \
# 0    685006  The apartment is right across the street from ...   75.0
# 1   9461238  Prime Williamsburg, the hot South side: Steps ...  117.0
# 2   4873690  Long Island City is the ultimate, in my mind, ...   89.0
# 3  12738047                                               None   80.0
# 4  15359479                                               None  200.0
#
#         diff                            listing_url  \
# 0   3.206529    https://www.airbnb.com/rooms/685006
# 1  57.554158   https://www.airbnb.com/rooms/9461238
# 2   2.726522   https://www.airbnb.com/rooms/4873690
# 3  19.614082  https://www.airbnb.com/rooms/12738047
# 4   9.892523  https://www.airbnb.com/rooms/15359479
#
#                                   name
# 0         Best Studio on Prospect Park
# 1     1 bedrms Williamsburg 1st Stop L
# 2  Private room, 10min to Times Square
# 3  clean and tidy separated livingroom
# 4    Awesome One Bedroom Gramercy Park

# %%
train.head()
# Out:
#            id                              neighborhood_overview  \
# 0    685006.0  The apartment is right across the street from ...
# 1   9461238.0  Prime Williamsburg, the hot South side: Steps ...
# 2   4873690.0  Long Island City is the ultimate, in my mind, ...
# 3  14179829.0  Located on a beautiful, quiet tree lined stree...
# 4   7364064.0  This spacious three bedroom is located in the ...
#
#       neighbourhood_cleansed      city   latitude  longitude
# 0  Prospect-Lefferts Gardens  Brooklyn  40.661408 -73.961750
# 1               Williamsburg  Brooklyn  40.716320 -73.957255
# 2           Long Island City    Queens  40.742824 -73.949939
# 3                  Sunnyside    Queens  40.741264 -73.925798
# 4            Stuyvesant Town  New York  40.733109 -73.979277

# %%
train = pd.read_sql_query("SELECT * FROM location_descriptions", con)

# %%
train.columns
# Out:
# Index(['id', 'neighborhood_overview', 'neighbourhood_cleansed', 'city',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
train = pd.read_sql_query("""
                          SELECT id, neighborhood_overview, neighbourhood_cleansed, latitude, longitude,
                          price, diff, listing_url, name FROM listings_price
                          """, con)

nbd_counts = train["neighbourhood_cleansed"].value_counts()
descp = train[["id", "neighborhood_overview"]]
descp = descp.drop_duplicates()

# %%
print("loading models")
model = joblib.load(os.path.join(home_folder, 'airbnb_app/Data/tf_idf_model.pkl'))

knn = NearestNeighbors(500, metric = "cosine", algorithm = "brute")
X = descp["neighborhood_overview"].dropna()

#somewhat slow - could save the projections first here:
X_proj = model.transform(X)

#fast since there's no real fittting going on here
#should check how fast predicting is - should be fine for a few values.
knn.fit(X_proj)
# Out:
# loading models
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=500, p=2, radius=1.0)

# %%
descp = "jamaican cusine culture gritty"

# %%
nbd_score = airbnb_pipeline.get_nbds(descp, knn, model, train, nbd_counts)

# %%
def get_colors(n):
    """
    color scales based on the new matplotlib scales with slight modifications
    """

    scales = [["#f2eff1", "#f2eff1", "#451077", "#721F81", "#9F2F7F", "#CD4071",
    "#F1605D",  "#FD9567",  "#FEC98D", "#FCFDBF"],

    ["#f2eff1", "#f2eff1", "#3E4A89", "#31688E", "#26828E", "#1F9E89", "#35B779",
    "#6DCD59", "#B4DE2C", "#FDE725"],

    ["#f2eff1", "#f2eff1", "#4B0C6B", "#781C6D", "#A52C60", "#CF4446",
    "#ED6925", "#FB9A06", "#F7D03C", "#FCFFA4"]]

    return(scales[n-1])

def return_color_scale(n):
    df = pd.Series(get_colors(n))
    df.index = np.power(df.index/10, 1/1.75)
    return df.to_dict()

def locations_of_best_match(new_descp, knn, model, train):
    neighbors = knn.kneighbors(model.transform([new_descp]))
    closest_listings = neighbors[1][0]
    results = train.iloc[closest_listings]
    return results

def get_heat_map(descp, knn, model, train):
    map_osm = folium.Map(tiles='cartodbdark_matter',
                         location = [40.7831, -73.970], zoom_start=13)
    results = locations_of_best_match(descp, knn, model, train)
    temp = results[["latitude", "longitude"]].values.tolist()

    map_osm.add_children(plugins.HeatMap(temp, min_opacity = 0.45,
                                         radius = 30, blur = 30,
                                         gradient = return_color_scale(1),
                                         name = descp))
    
    for i in range(10):
        folium.Marker([results.iloc[i].latitude, results.iloc[i].longitude], 
                      popup=results.iloc[i].neighborhood_overview).add_to(map_osm)

    return map_osm

# %%
results = locations_of_best_match(descp, knn, model, train)

# %%
results = locations_of_best_match(descp, knn, model, train)

# %%
results
# Out:
#              id                              neighborhood_overview  \
# 22205   1217046  The apartment is in the heart of Williamsburg,...
# 10736   6437014  Park Slope is considered one of New York City'...
# 11561  15287313                                               None
# 11558  15025178  My neighborhood is up and coming, funky, diver...
# 17904   9512844  Very safe neighborhood - quiet and clean. Grea...
# 14641  11211612                                               None
# 19238   3463475  The neighborhood is a nightlife hub on weekend...
# 22036  15513170                                               None
# 16051  13961073  Hell's Kitchen is perfectly located for you to...
# 11794   1523556  The neighborhood is unique as its right betwee...
# 21917  11844315  The apartment is located in Stuyvestant Height...
# 11938   9387436                                               None
# 11939   6897066  The apartment is located right in front of a n...
# 18140   4121110  Lovely side street on the Upper West Side of M...
# 6129    3627589  Quiet, tree-lined, and friendly people. Very s...
# 21831   2410819                                               None
# 12268  12794405  Bed-Stuy is a gentrifying area. There is a mix...
# 11419  15550805                                               None
# 19072   8716711  Metropolitan museum of Art and Central Park is...
# 21395   4531990  The apartment is located on the outskirts of B...
# 12239   8993422                                               None
# 8044   13467433                                               None
# 14900  10366328  There are plenty of bars and restaurants so yo...
# 11559  13452316                                               None
# 18139   7660047  Within the Bronx you can visit the New York Bo...
# 13399   4533347  Bars, Music, Theatre, Nightlife, Parks, Commun...
# 10394  10310103                                               None
# 9181    8612715  Astoria, is one of the safest and trendiest ne...
# 1521    7729804  Northern Crown Heights is an very diverse neig...
# 20233  14601273  Lots of restaurants and shops and very conveni...
# ...         ...                                                ...
# 10311   9393610  The Williamsburg area is amazing, and have end...
# 8795   10843988                                               None
# 13004   1518302                                               None
# 12790   9515435  Bed-Stuy is located in central Brooklyn and nu...
# 16459   8978525  Around the corner from Franklin avenue with ma...
# 6354    3644032  Park Slope is a popular and historic neighborh...
# 10173   6249333  Little Russia by the Sea- this unique Eastern ...
# 17560  12774885  Situated close to the  park, hospital library ...
# 7735   12009678  After all the information about the apartment,...
# 15211  13044815                                               None
# 22387  14332710                                               None
# 9204   16202884                                               None
# 11324   7554629                                               None
# 11325  10215758  Williamsburg is the epicenter of fashionable B...
# 15701  11601634  The neighborhood is absolutely fabulous with t...
# 16590   6355664  Great neighborhood, Restaurants, museum, Prosp...
# 16514  14483355                                               None
# 22092  14935831                                               None
# 18529  16180645  Astoria is a very diverse neighborhood with a ...
# 7710   15957209                                               None
# 15400  12914312                                               None
# 16520   6520814                                               None
# 6497    5346488  This neighborhood has everything you could nee...
# 4094   16103920  A tan sólo unos metros se encuentran casi toda...
# 2313    6673748  Your in Soho Little Italy.. One of hte greates...
# 18775   7265918  The West Village ! Famous for it's Jazz clubs,...
# 5351    7579241  This location is close to everything in the ci...
# 21137   5030058                                               None
# 21138    704669                                               None
# 10029  13066912  Waters edge condo, close to everything.  Great...
#
#       neighbourhood_cleansed   latitude  longitude  price        diff  \
# 22205           Williamsburg  40.713168 -73.948511  250.0  -47.514673
# 10736            South Slope  40.666316 -73.990132  120.0   17.797299
# 11561        Upper East Side  40.770456 -73.952237  133.0   31.645662
# 11558               Bushwick  40.686089 -73.915714   65.0    4.063596
# 17904            East Harlem  40.792248 -73.944230  345.0  -66.895721
# 14641           Williamsburg  40.714995 -73.950001   50.0   38.514264
# 19238        Lower East Side  40.718118 -73.986186  126.0   62.308755
# 22036     Washington Heights  40.837788 -73.942184   55.0   23.273250
# 16051           Civic Center  40.712502 -74.005241  135.0   -0.567293
# 11794           Williamsburg  40.710411 -73.938474  178.0 -115.258575
# 21917     Bedford-Stuyvesant  40.682822 -73.936022  100.0   12.230483
# 11938     Bedford-Stuyvesant  40.689254 -73.944615  130.0  -29.633136
# 11939                   SoHo  40.726938 -74.003426  235.0  -14.357383
# 18140        Upper West Side  40.791454 -73.977091  195.0  -30.587399
# 6129      Bedford-Stuyvesant  40.685995 -73.951821   36.0   -0.000017
# 21831           East Village  40.729161 -73.980221  125.0   -3.214317
# 12268     Bedford-Stuyvesant  40.686597 -73.918777   65.0  -16.245291
# 11419                 Harlem  40.811248 -73.942173  150.0  -73.736964
# 19072        Upper East Side  40.776985 -73.958402  550.0 -283.731017
# 21395     Bedford-Stuyvesant  40.681571 -73.920235   75.0  -31.160984
# 12239            Columbia St  40.689198 -73.999710  175.0  -21.490860
# 8044      Financial District  40.707063 -74.004419   99.0    9.705000
# 14900               Gramercy  40.733017 -73.981547   90.0   35.333799
# 11559            Fort Greene  40.687174 -73.978494   60.0   27.778626
# 18139         Morris Heights  40.849490 -73.914996   40.0    7.990105
# 13399           East Village  40.729071 -73.985618  200.0 -101.313908
# 10394           Williamsburg  40.714393 -73.944368  110.0   10.082233
# 9181                 Astoria  40.762577 -73.921406   70.0   -6.738967
# 1521           Crown Heights  40.675171 -73.944214   50.0   20.892739
# 10394                Large Sunny Lofted Cabin House Room
# 9181                 NYC-Room,NoHiddenFees+FreeBreakfast
# 1521                   Spacious Pre-War in Crown Heights
# 20233                                  Stunning NYC home
# ...                                                  ...
# 10311                 Big room in Williamsburg Penthouse
# 8795                 Amazing HUGE NewlyRenovated 2BDRM!!
# 13004                        Central Manhattan 1 bedroom
# 12790          Charming two-floor brownstone in Bed Stuy
# 16459                                 Crown Heights Room
# 6354                    Light-Filled Haven in Park Slope
# 10173                       Summer Bungalow by the Beach
# 17560                Spacious, cozy bedroom in a private
# 7735                  Ground floor studio with garden NY
# 15211                            Private room available!
# 22387     Spacious Apartment in Manhattan - great views!
# 9204      Stylish Studio Apartment close to Central Park
# 11324                          Beautiful Room - Gramercy
# 11325                       Modern designer Williamsburg
# 15701                Two-Bedroom Duplex in Williamsburg!
# 16590                      Spacious 1 bedroom apartment.
# 16514              Spacious Apartment near Prospect Park
# 22092    Bright 3BR, 2 FULL BATH (15 MINS to MANHATTAN!)
# 18529      Private room 15 minutes to Midtown Manhattan.
# 7710      Cozy private bedroom in East Village, New York
# 15400                    Private room in Trendy Bushwick
# 16520                Beautiful, Spacious, Great Location
# 6497                       Huge Sunny Room With En Suite
# 4094                          Nice Apartment MeatPacking
# 2313                      Mott St Soho Studio - Sleeps 4
# 18775                     West Village. Cultural Center.
# 5351                  A True Gem A-List InteriorDesigner
# 21137                   Chic & Central, West Village NYC
# 21138                     Sunny Loft Studio, Fort Greene
# 10029                Private Master Bdrm in Luxury Condo
#
# [500 rows x 9 columns]

# %%
descp
# Out:
# 'jamaican cusine culture gritty'

# %%
map_osm = folium.Map(tiles='cartodbdark_matter',
                         location = [40.7831, -73.970], zoom_start=13)
results = locations_of_best_match(descp, knn, model, train)
temp = results[["latitude", "longitude"]].values.tolist()

map_osm.add_children(plugins.HeatMap(temp, min_opacity = 0.45,
                                     radius = 30, blur = 30,
                                     gradient = return_color_scale(1),
                                     name = descp))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
html="""
    <h1> This is a big popup</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """
iframe = folium.element.IFrame(html=html, width=500, height=300)
popup = folium.Popup(iframe, max_width=2650)

# %%
train
# Out:
#              id                              neighborhood_overview  \
# 0        685006  The apartment is right across the street from ...
# 1       9461238  Prime Williamsburg, the hot South side: Steps ...
# 2       4873690  Long Island City is the ultimate, in my mind, ...
# 3      12738047                                               None
# 4      15359479                                               None
# 5      14179829  Located on a beautiful, quiet tree lined stree...
# 6        810483                                               None
# 7       9854420                                               None
# 8       4349358  The apartment is located in a beautiful, safe,...
# 9       9330135                                               None
# 10     14310864                                               None
# 11      1465807                                               None
# 12     11165126  Architecture, art, and fine dining meets a thr...
# 13     16014791  I love the convenient of walking distance to e...
# 14     16145655                                               None
# 15      7344066                                               None
# 16      9461187                                               None
# 17     15752636                                               None
# 18      1727923  Williamsburg is the most dynamic neighborhood ...
# 19     11296173                                               None
# 20      7364008                                               None
# 21     15097255                                               None
# 22      3562906  This is centrally located in midtown. Times Sq...
# 23      8699290  Around the Corner on 111th (btw 2nd & 3rd) the...
# 13      Nice clean style apt. Central midtwn near Javits
# 14       Spacious 1-bd, sleeps 4, 20 min to Times Square
# 15                       Gorgeous West Village 1-bdm apt
# 16                   Apartment 20 minutes from Manhattan
# 17                     Spacious Private Room in Brooklyn
# 18        Large private 1BR with backyard - Williamsburg
# 19                      Lovely NYC Apartment  July 16-30
# 20                   Bohéme 1BR steps from Prospect Park
# 21                Luxury 1 Br in Luxury Doorman Building
# 22                   HighRise Studio-Walk 2 Times Square
# 23                               Private Room Great Area
# 24                            Bedroom for two in Chelsea
# 25                        APT IN PROSPECT/CROWN HEIGHTS
# 26                    Quiet*Spacious*Private Bath*Sunny!
# 27                    Modern NY apt in the East Village!
# 28                   Spacious, Well-Lit Comfortable Apt!
# 29                       Beautiful private bedroom - LIC
# ...                                                  ...
# 39631                                 Private Bedroom #5
# 39632                                 Private Bedroom #2
# 39633                                    Private room #3
# 39634                         Friendly and Inviting Home
# 39635                                 Private Bedroom #1
# 39636                               Private Queen Bed #4
# 39637                        Room for rent. Quiet, safe.
# 39638                Spacious 3 BR APT in Midtown(5/6AVE
# 39639                 Very private & large room Wburg BK
# 39640     Comfortable One Private Bedroom near Manhattan
# 39641  LIC/Astoria Two Bed Apt 10 minutes from Manhattan
# 39642                 Lovely Private room near Manhattan
# 39643                   Light filled modern APT in DUMBO
# 39644                       Private Studio; Near All NYC
# 39645                   Bedroom in Williamsburg, BK, NYC
# 39646                        Very bright room in 3BD/2BR
# 39647                  Gramercy: Convenient Bright Quiet
# 39648  Charming 1BR A in townhouse with modern amenities
# 39649  Charming 1BR B in townhouse with modern amenities
# 39650    Charming 2BR in townhouse with modern amenities
# 39651                                Home Away from Home
# 39652                Holiday in Heart of Time Square/NYC
# 39653                Brandnew Luxury flat in Time Square
# 39654                2bdr Flat - Xmass in Time Squre NYC
# 39655                  cute and clean in trendy Bushwick
# 39656                          Big room in private house
# 39657                A room in private house, small room
# 39658                       A nice room in private house
# 39659                 Home away from home in heart of BK
# 39660                   Your beach-side bungalow awaits!
#
# [39661 rows x 9 columns]

# %%
results
# Out:
#              id                              neighborhood_overview  \
# 22205   1217046  The apartment is in the heart of Williamsburg,...
# 10736   6437014  Park Slope is considered one of New York City'...
# 11561  15287313                                               None
# 11558  15025178  My neighborhood is up and coming, funky, diver...
# 17904   9512844  Very safe neighborhood - quiet and clean. Grea...
# 14641  11211612                                               None
# 19238   3463475  The neighborhood is a nightlife hub on weekend...
# 22036  15513170                                               None
# 16051  13961073  Hell's Kitchen is perfectly located for you to...
# 11794   1523556  The neighborhood is unique as its right betwee...
# 21917  11844315  The apartment is located in Stuyvestant Height...
# 11938   9387436                                               None
# 11939   6897066  The apartment is located right in front of a n...
# 18140   4121110  Lovely side street on the Upper West Side of M...
# 6129    3627589  Quiet, tree-lined, and friendly people. Very s...
# 21831   2410819                                               None
# 12268  12794405  Bed-Stuy is a gentrifying area. There is a mix...
# 11419  15550805                                               None
# 19072   8716711  Metropolitan museum of Art and Central Park is...
# 21395   4531990  The apartment is located on the outskirts of B...
# 12239   8993422                                               None
# 8044   13467433                                               None
# 14900  10366328  There are plenty of bars and restaurants so yo...
# 11559  13452316                                               None
# 18139   7660047  Within the Bronx you can visit the New York Bo...
# 13399   4533347  Bars, Music, Theatre, Nightlife, Parks, Commun...
# 10394  10310103                                               None
# 9181    8612715  Astoria, is one of the safest and trendiest ne...
# 1521    7729804  Northern Crown Heights is an very diverse neig...
# 20233  14601273  Lots of restaurants and shops and very conveni...
# ...         ...                                                ...
# 10311   9393610  The Williamsburg area is amazing, and have end...
# 8795   10843988                                               None
# 13004   1518302                                               None
# 12790   9515435  Bed-Stuy is located in central Brooklyn and nu...
# 16459   8978525  Around the corner from Franklin avenue with ma...
# 6354    3644032  Park Slope is a popular and historic neighborh...
# 10173   6249333  Little Russia by the Sea- this unique Eastern ...
# 17560  12774885  Situated close to the  park, hospital library ...
# 7735   12009678  After all the information about the apartment,...
# 15211  13044815                                               None
# 22387  14332710                                               None
# 9204   16202884                                               None
# 11324   7554629                                               None
# 11325  10215758  Williamsburg is the epicenter of fashionable B...
# 15701  11601634  The neighborhood is absolutely fabulous with t...
# 16590   6355664  Great neighborhood, Restaurants, museum, Prosp...
# 16514  14483355                                               None
# 22092  14935831                                               None
# 18529  16180645  Astoria is a very diverse neighborhood with a ...
# 7710   15957209                                               None
# 15400  12914312                                               None
# 16520   6520814                                               None
# 6497    5346488  This neighborhood has everything you could nee...
# 4094   16103920  A tan sólo unos metros se encuentran casi toda...
# 2313    6673748  Your in Soho Little Italy.. One of hte greates...
# 18775   7265918  The West Village ! Famous for it's Jazz clubs,...
# 5351    7579241  This location is close to everything in the ci...
# 21137   5030058                                               None
# 21138    704669                                               None
# 10029  13066912  Waters edge condo, close to everything.  Great...
#
#       neighbourhood_cleansed   latitude  longitude  price        diff  \
# 22205           Williamsburg  40.713168 -73.948511  250.0  -47.514673
# 10736            South Slope  40.666316 -73.990132  120.0   17.797299
# 11561        Upper East Side  40.770456 -73.952237  133.0   31.645662
# 11558               Bushwick  40.686089 -73.915714   65.0    4.063596
# 17904            East Harlem  40.792248 -73.944230  345.0  -66.895721
# 14641           Williamsburg  40.714995 -73.950001   50.0   38.514264
# 19238        Lower East Side  40.718118 -73.986186  126.0   62.308755
# 22036     Washington Heights  40.837788 -73.942184   55.0   23.273250
# 16051           Civic Center  40.712502 -74.005241  135.0   -0.567293
# 11794           Williamsburg  40.710411 -73.938474  178.0 -115.258575
# 21917     Bedford-Stuyvesant  40.682822 -73.936022  100.0   12.230483
# 11938     Bedford-Stuyvesant  40.689254 -73.944615  130.0  -29.633136
# 11939                   SoHo  40.726938 -74.003426  235.0  -14.357383
# 18140        Upper West Side  40.791454 -73.977091  195.0  -30.587399
# 6129      Bedford-Stuyvesant  40.685995 -73.951821   36.0   -0.000017
# 21831           East Village  40.729161 -73.980221  125.0   -3.214317
# 12268     Bedford-Stuyvesant  40.686597 -73.918777   65.0  -16.245291
# 11419                 Harlem  40.811248 -73.942173  150.0  -73.736964
# 16051                                Queen of the Castle
# 11794  Simply brooklyn. Bedroom with office off L train.
# 21917                    Large, Sunny Brooklyn Apartment
# 11938                         Rhonda's bed and breakfast
# 11939                        Fantastic 1 Bedroom in Soho
# 18140        Upper West Side studio with private terrace
# 6129                           Cozy Single private room.
# 21831                      In the heart of Alphabet City
# 12268                Private room, bathroom, and balcony
# 11419        Private Urban Harlem Apartment in Manhattan
# 19072                2 bedroom family apt close to park!
# 21395                   Charming and Clean Brooklyn Apt.
# 12239                  Huge duplex apartment in Brooklyn
# 8044   This is NYC-Amazing Bedroom at Financial District
# 14900                   Huge Private bd/b - East Village
# 11559  Spacious, light filled room in a luxury building.
# 18139                       Big Room in the Heart of NYC
# 13399                 Beautiful Oasis in Prime Location!
# 10394                Large Sunny Lofted Cabin House Room
# 9181                 NYC-Room,NoHiddenFees+FreeBreakfast
# 1521                   Spacious Pre-War in Crown Heights
# 20233                                  Stunning NYC home
# ...                                                  ...
# 10311                 Big room in Williamsburg Penthouse
# 8795                 Amazing HUGE NewlyRenovated 2BDRM!!
# 13004                        Central Manhattan 1 bedroom
# 12790          Charming two-floor brownstone in Bed Stuy
# 16459                                 Crown Heights Room
# 6354                    Light-Filled Haven in Park Slope
# 10173                       Summer Bungalow by the Beach
# 17560                Spacious, cozy bedroom in a private
# 7735                  Ground floor studio with garden NY
# 15211                            Private room available!
# 22387     Spacious Apartment in Manhattan - great views!
# 9204      Stylish Studio Apartment close to Central Park
# 11324                          Beautiful Room - Gramercy
# 11325                       Modern designer Williamsburg
# 15701                Two-Bedroom Duplex in Williamsburg!
# 16590                      Spacious 1 bedroom apartment.
# 16514              Spacious Apartment near Prospect Park
# 22092    Bright 3BR, 2 FULL BATH (15 MINS to MANHATTAN!)
# 18529      Private room 15 minutes to Midtown Manhattan.
# 7710      Cozy private bedroom in East Village, New York
# 15400                    Private room in Trendy Bushwick
# 16520                Beautiful, Spacious, Great Location
# 6497                       Huge Sunny Room With En Suite
# 4094                          Nice Apartment MeatPacking
# 2313                      Mott St Soho Studio - Sleeps 4
# 18775                     West Village. Cultural Center.
# 5351                  A True Gem A-List InteriorDesigner
# 21137                   Chic & Central, West Village NYC
# 21138                     Sunny Loft Studio, Fort Greene
# 10029                Private Master Bdrm in Luxury Condo
#
# [500 rows x 9 columns]

# %%
for i in range(10):
    
    html = """<h1> <a href = {0} target="_blank"> View on AirBnB </a> </h1>
              <p> {1} </p>
              
           """.format(results.iloc[i].listing_url ,results.iloc[i]["name"])
    iframe = folium.element.IFrame(html=html, width=500, height=300)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([results.iloc[i].latitude,
                   results.iloc[i].longitude],
                   popup=popup).add_to(map_osm)

# %%
results.iloc[10].neighborhood_overview
# Out:
# 'The apartment is located in Stuyvestant Heights, a quiet and historic Brooklyn neighborhood, filled with beautiful brownstone buildings. The apartment is only a block away from Saraghina, a delicious pizza place and bakery. There are a ton of other restaurants nearby including Peaches, Georges Andre, Tepache Mexican, and Il Lunatico.'

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
